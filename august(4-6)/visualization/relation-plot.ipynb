# %%
import pandas as pd
import numpy as np

import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_excel("Apocolypse Food Prep.xlsx")
df.head()
# Out:
#      Store Product  Price       Date
# 0  Walmart    Rice  25.00 2022-01-01
# 1   Costco    Rice  23.00 2022-01-01
# 2   Target    Rice  22.99 2022-01-01
# 3  Walmart    Rice  25.75 2022-02-01
# 4   Costco    Rice  23.99 2022-02-01

# %%
# df.Date = pd.to_datetime(pd['Date'])
import random

df.loc[:,'Selling_Price'] = df.Price.map(lambda x : round((x - (x/random.randint(2,3))),2))
df
# Out:
#       Store            Product  Price       Date  Selling_Price
# 0   Walmart               Rice  25.00 2022-01-01          16.67
# 1    Costco               Rice  23.00 2022-01-01          11.50
# 2    Target               Rice  22.99 2022-01-01          15.33
# 3   Walmart               Rice  25.75 2022-02-01          17.17
# 4    Costco               Rice  23.99 2022-02-01          11.99
# 5    Target               Rice  23.25 2022-02-01          11.62
# 6   Walmart               Rice  26.99 2022-03-01          17.99
# 7    Costco               Rice  24.99 2022-03-01          16.66
# 8    Target               Rice  24.25 2022-03-01          12.12
# 9   Walmart               Rice  26.99 2022-04-01          17.99
# 10   Costco               Rice  25.25 2022-04-01          16.83
# 11   Target               Rice  24.75 2022-04-01          16.50
# 12  Walmart        Dried Beans  22.99 2022-01-01          15.33
# 13   Costco        Dried Beans  20.99 2022-01-01          10.49
# ...

# %%
sns.relplot(data=df, x = 'Store', y = 'Selling_Price',kind='line',col='Product')

# %%
sns.relplot(data=df, x = 'store', y='Price', kind='line', hue='Product',col='Store')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\VS CODE\ML\DS\august(4-6)\visualization\relation-plot.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/VS%20CODE/ML/DS/august%284-6%29/visualization/relation-plot.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> sns.relplot(data=df, x = 'store', y='Price', kind='line', hue='Product',col='Store')
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\relational.py:862, in relplot(data, x, y, hue, size, style, units, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     859     kwargs.pop("ax")
#     861 # Use the full dataset to map the semantics
# --> 862 p = plotter(
#     863     data=data,
#     864     variables=plotter.get_semantics(locals()),
# ...

# %%
sns.relplot(data=df, x = 'Store', y='Price', kind='line', hue='Product',row='Product')
