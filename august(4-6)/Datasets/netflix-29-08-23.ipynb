# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('netflix_titles.csv')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df[df.duration.isna()]
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country          date_added  release_year  rating  \
# 5541  Louis C.K.  United States       April 4, 2017          2017  74 min
# 5794  Louis C.K.  United States  September 16, 2016          2010  84 min
# 5813  Louis C.K.  United States     August 15, 2016          2015  66 min
#
#      duration listed_in                                        description
# 5541      NaN    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794      NaN    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813      NaN    Movies  The comic puts his trademark hilarious/thought...

# %%
df[df.director.isna()].director = '-'
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_11280\2009450807.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df.director.isna()].director = '-'

# %%
df[df.director.isna()]
# Out:
#      show_id     type                                title director  \
# 1         s2  TV Show                        Blood & Water      NaN
# 3         s4  TV Show                Jailbirds New Orleans      NaN
# 4         s5  TV Show                         Kota Factory      NaN
# 10       s11  TV Show  Vendetta: Truth, Lies and The Mafia      NaN
# 14       s15  TV Show      Crime Stories: India Detectives      NaN
# ...      ...      ...                                  ...      ...
# 8795   s8796  TV Show                      Yu-Gi-Oh! Arc-V      NaN
# 8796   s8797  TV Show                           Yunus Emre      NaN
# 8797   s8798  TV Show                            Zak Storm      NaN
# 8800   s8801  TV Show                   Zindagi Gulzar Hai      NaN
# 8803   s8804  TV Show                          Zombie Dumb      NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
tv_show = df[df.type == 'TV Show']
tv_show
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V              NaN
# 8796   s8797  TV Show             Yunus Emre              NaN
# 8797   s8798  TV Show              Zak Storm              NaN
# 8800   s8801  TV Show     Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
movies = df[df.type == 'Movie']
movies
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
movies[movies.director.isna()].loc[:, 'director'] = '-'

# %%
movies[movies.director.isna()].director = '-'
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_11280\1674056930.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies[movies.director.isna()].director = '-'

# %%
movies[movies.director.isna()]
# Out:
#      show_id   type                          title director  \
# 404     s405  Movie  9to5: The Story of a Movement      NaN
# 470     s471  Movie    Bridgerton - The Afterparty      NaN
# 483     s484  Movie                    Last Summer      NaN
# 641     s642  Movie               Sisters on Track      NaN
# 717     s718  Movie    Headspace: Unwind Your Mind      NaN
# ...      ...    ...                            ...      ...
# 8231   s8232  Movie                       The Bund      NaN
# 8268   s8269  Movie               The Darkest Dawn      NaN
# 8330   s8331  Movie               The Great Battle      NaN
# 8647   s8648  Movie    Twisted Trunk, Big Fat Body      NaN
# 8784   s8785  Movie           Yoko and His Friends      NaN
#
#                                                    cast         country  \
# 404                                                 NaN             NaN
# 470        David Spade, London Hughes, Fortune Feimster             NaN
# ...

# %%
movies.director.isna().sum()
# Out:
# 188

# %%
movies.rating.isna().sum()
# Out:
# 2

# %%
tv_show.rating.isna().sum()
# Out:
# 2

# %%
tv_show.director.isna().sum()
# Out:
# 2446

# %%
movies[movies.director.isna()].director = 'NA'
# movies[movies.director.isna()]
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_11280\4181838945.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies[movies.director.isna()].director = 'NA'

# %%
movies[movies.director.isna()].loc[:,'director'] = 'NA'
director_nan = movies[movies.director.isna()].index

# %%
movies.loc[director_nan,:].director = 'NA'
movies.director.isna()
# Out:
# 0       False
# 6       False
# 7       False
# 9       False
# 12      False
#         ...
# 8801    False
# 8802    False
# 8804    False
# 8805    False
# 8806    False
# Name: director, Length: 6131, dtype: bool

# %%
movies.isna().sum()
# Out:
# show_id           0
# type              0
# title             0
# director        188
# cast            475
# country         440
# date_added        0
# release_year      0
# rating            2
# duration          3
# listed_in         0
# description       0
# dtype: int64

# %%
movies[movies.director.isna()].loc[:, 'director'] = '-'

# %%
movies.director.isna().sum()
# Out:
# 188

# %%
ind = movies[movies.director.isna()].index
movies.loc[ind, 'director'] = '-'

# %%
movies.director.isna().sum()
# Out:
# 0

# %%
wrong_rating = movies[movies.duration.isna()].index
wrong_rating
# Out:
# Index([5541, 5794, 5813], dtype='int64')

# %%
movies.loc[wrong_rating,'duration'] = movies.loc[wrong_rating,'rating']

# %%
movies.duration.isna().any()
# Out:
# False

# %%
movies.loc[wrong_rating,'rating'] = None

# %%
movies[movies.rating.isna()]
# Out:
#      show_id   type                                              title  \
# 5541   s5542  Movie                                    Louis C.K. 2017
# 5794   s5795  Movie                              Louis C.K.: Hilarious
# 5813   s5814  Movie               Louis C.K.: Live at the Comedy Store
# 5989   s5990  Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
# 7537   s7538  Movie                               My Honor Was Loyalty
#
#              director                                               cast  \
# 5541       Louis C.K.                                         Louis C.K.
# 5794       Louis C.K.                                         Louis C.K.
# 5813       Louis C.K.                                         Louis C.K.
# 5989                -                        Oprah Winfrey, Ava DuVernay
# 7537  Alessandro Pepe  Leone Frisa, Paolo Vaccarino, Francesco Miglio...
#
#             country          date_added  release_year rating duration  \
# ...

# %%
# movies.rating[movies.show_id == 's5990'] = 'TV-PG'

# %%
# movies.rating[movies.show_id == 's7538'] = 'PG-13'

# %%
movies.rating[movies.show_id == 's5814'] = 'TV-MA'
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_11280\829737049.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies.rating[movies.show_id == 's5814'] = 'TV-MA'

# %%
movies.rating[movies.show_id == 's5795'] = 'TV-MA'
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_11280\2970375412.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies.rating[movies.show_id == 's5795'] = 'TV-MA'

# %%
mmode = movies.rating.mode()
mmode[0]
# Out:
# 'TV-MA'

# %%
ratind = movies[movies.rating.isna()].index
ratind
# Out:
# Index([5541, 5989, 7537], dtype='int64')

# %%
movies.loc[ratind,'rating'] = mmode[0]

# %%
movies[movies.rating.isna()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
tv_show.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2446
# cast             350
# country          391
# date_added        10
# release_year       0
# rating             2
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
tv_show.director[tv_show.director.isna()] = '-'
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_11280\2135136772.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_show.director[tv_show.director.isna()] = '-'

# %%
tv_show.director.isna().any()
# Out:
# False

# %%
tv_show.rating[tv_show.title == 'Gargantia on the Verdurous Planet'] = 'TV-PG'
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_11280\1718728262.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_show.rating[tv_show.title == 'Gargantia on the Verdurous Planet'] = 'TV-PG'

# %%
tv_show.rating[tv_show.title == 'Little Lunch'] = 'TV-G'
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_11280\2595359752.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_show.rating[tv_show.title == 'Little Lunch'] = 'TV-G'

# %%
tv_show[tv_show.rating.isna()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
tv_show.release_year.mode()
# Out:
# 0    2020
# Name: release_year, dtype: int64

# %%
tv_show.date_added = tv_show.date_added.astype('str')
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_11280\274621520.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_show.date_added = tv_show.date_added.astype('str')

# %%
tv_show.date_added = tv_show.date_added.apply(lambda x : x.split()[0])
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_11280\4188802006.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_show.date_added = tv_show.date_added.apply(lambda x : x.split()[0])

# %%
delay = tv_show.date_added.mode()

# %%
tv_show.date_added[tv_show.date_added.isna()] = delay
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_11280\270570575.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_show.date_added[tv_show.date_added.isna()] = delay

# %%
tv_show.cast[tv_show.cast.isna()] = '-'
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_11280\969456924.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_show.cast[tv_show.cast.isna()] = '-'

# %%
tv_show.country[tv_show.country.isna()] = '-'
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_11280\4014543668.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_show.country[tv_show.country.isna()] = '-'

# %%
tv_show.isna().any()
# Out:
# show_id         False
# type            False
# title           False
# director        False
# cast            False
# country         False
# date_added      False
# release_year    False
# rating          False
# duration        False
# listed_in       False
# description     False
# dtype: bool
