# %%
import pandas as pd
import polars as pl
import numpy as np

# %%
df = pd.read_csv('titanic1.csv')
df.head(100)
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# ..          ...       ...     ...
# 95          987         0       3
# 96          988         1       1
# 97          989         0       3
# 98          990         1       3
# 99          991         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                                    Kelly, Mr. James    male  34.5      0
# 1                    Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                           Myles, Mr. Thomas Francis    male  62.0      0
# 3                                    Wirz, Mr. Albert    male  27.0      0
# 4        Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ..                                                ...     ...   ...    ...
# ...

# %%
df2 = pl.read_csv('titanic1.csv')
df2.head()
# Out:
# shape: (5, 12)
# ┌─────────────┬──────────┬────────┬─────────────────────┬───┬─────────┬─────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name                ┆ … ┆ Ticket  ┆ Fare    ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---                 ┆   ┆ ---     ┆ ---     ┆ ---   ┆ ---      │
# │ i64         ┆ i64      ┆ i64    ┆ str                 ┆   ┆ str     ┆ f64     ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪═════════════════════╪═══╪═════════╪═════════╪═══════╪══════════╡
# │ 892         ┆ 0        ┆ 3      ┆ Kelly, Mr. James    ┆ … ┆ 330911  ┆ 7.8292  ┆ null  ┆ Q        │
# │ 893         ┆ 1        ┆ 3      ┆ Wilkes, Mrs. James  ┆ … ┆ 363272  ┆ 7.0     ┆ null  ┆ S        │
# │             ┆          ┆        ┆ (Ellen Needs)       ┆   ┆         ┆         ┆       ┆          │
# │ 894         ┆ 0        ┆ 2      ┆ Myles, Mr. Thomas   ┆ … ┆ 240276  ┆ 9.6875  ┆ null  ┆ Q        │
# ...

# %%
df2.describe()
# Out:
# shape: (9, 13)
# ┌────────────┬─────────────┬──────────┬──────────┬───┬─────────────┬───────────┬───────┬──────────┐
# │ describe   ┆ PassengerId ┆ Survived ┆ Pclass   ┆ … ┆ Ticket      ┆ Fare      ┆ Cabin ┆ Embarked │
# │ ---        ┆ ---         ┆ ---      ┆ ---      ┆   ┆ ---         ┆ ---       ┆ ---   ┆ ---      │
# │ str        ┆ f64         ┆ f64      ┆ f64      ┆   ┆ str         ┆ f64       ┆ str   ┆ str      │
# ╞════════════╪═════════════╪══════════╪══════════╪═══╪═════════════╪═══════════╪═══════╪══════════╡
# │ count      ┆ 418.0       ┆ 418.0    ┆ 418.0    ┆ … ┆ 418         ┆ 418.0     ┆ 418   ┆ 418      │
# │ null_count ┆ 0.0         ┆ 0.0      ┆ 0.0      ┆ … ┆ 0           ┆ 1.0       ┆ 327   ┆ 0        │
# │ mean       ┆ 1100.5      ┆ 0.363636 ┆ 2.26555  ┆ … ┆ null        ┆ 35.627188 ┆ null  ┆ null     │
# │ std        ┆ 120.810458  ┆ 0.481622 ┆ 0.841838 ┆ … ┆ null        ┆ 55.907576 ┆ null  ┆ null     │
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
fare = 79
df.query('Name.str.startswith("Ryerson") and Fare > 79')
# Out:
#      PassengerId  Survived  Pclass  \
# 24           916         1       1
# 64           956         0       1
# 142         1034         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 24   Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 64                       Ryerson, Master. John Borie    male  13.0      2
# 142                       Ryerson, Mr. Arthur Larned    male  61.0      1
#
#      Parch    Ticket     Fare            Cabin Embarked
# 24       3  PC 17608  262.375  B57 B59 B63 B66        C
# 64       2  PC 17608  262.375  B57 B59 B63 B66        C
# 142      3  PC 17608  262.375  B57 B59 B63 B66        C

# %%
print(df.groupby('Sex')['Age'].agg(['count','mean', 'min','max','var']))
print()
print(df.groupby('Pclass').get_group(2)['Age'].agg(['count','mean']))
# Out:
#         count       mean   min   max         var
# Sex
# female    121  30.550331  0.17  76.0  242.567323
# male      201  30.263234  0.33  67.0  181.996663
#
# count    88.0000
# mean     28.7775
# Name: Age, dtype: float64

# %%
df['Age'].diff()
# Out:
# 0       NaN
# 1      12.5
# 2      15.0
# 3     -35.0
# 4      -5.0
#        ...
# 413     NaN
# 414     NaN
# 415    -0.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
df.Sex.astype('category')
# Out:
# 0        male
# 1      female
# 2        male
# 3        male
# 4      female
#         ...
# 413      male
# 414    female
# 415      male
# 416      male
# 417      male
# Name: Sex, Length: 418, dtype: category
# Categories (2, object): ['female', 'male']

# %%
df3 = pd.read_csv("2023_Countries by Population.csv")
df3.head()
# Out:
#    place      pop1980       pop2000       pop2010       pop2022       pop2023  \
# 0    356  696828385.0  1.059634e+09  1.240614e+09  1.417173e+09  1.428628e+09
# 1    156  982372466.0  1.264099e+09  1.348191e+09  1.425887e+09  1.425671e+09
# 2    840  223140018.0  2.823986e+08  3.111828e+08  3.382899e+08  3.399966e+08
# 3    360  148177096.0  2.140724e+08  2.440162e+08  2.755013e+08  2.775341e+08
# 4    586   80624057.0  1.543699e+08  1.944545e+08  2.358249e+08  2.404857e+08
#
#         pop2030       pop2050        country       area  landAreaKm cca2 cca3  \
# 0  1.514994e+09  1.670491e+09          India  3287590.0   2973190.0   IN  IND
# 1  1.415606e+09  1.312636e+09          China  9706961.0   9424702.9   CN  CHN
# 2  3.521623e+08  3.753920e+08  United States  9372610.0   9147420.0   US  USA
# 3  2.921501e+08  3.172252e+08      Indonesia  1904569.0   1877519.0   ID  IDN
# 4  2.740298e+08  3.678085e+08       Pakistan   881912.0    770880.0   PK  PAK
#
# ...

# %%
df3.query('country == "India"')[['pop2000','pop2010','pop2022','pop2023']].agg(['mean','max','min'])
# df3.query('country == "India"')
# Out:
#            pop2000       pop2010       pop2022       pop2023
# mean  1.059634e+09  1.240614e+09  1.417173e+09  1.428628e+09
# max   1.059634e+09  1.240614e+09  1.417173e+09  1.428628e+09
# min   1.059634e+09  1.240614e+09  1.417173e+09  1.428628e+09

# %%
df3.query('place > 300').country
# Out:
# 0                          India
# 2                  United States
# 3                      Indonesia
# 4                       Pakistan
# 5                        Nigeria
#                  ...
# 228    Saint Pierre and Miquelon
# 229                   Montserrat
# 231                         Niue
# 232                      Tokelau
# 233                 Vatican City
# Name: country, Length: 154, dtype: object

# %%
df1 = pd.DataFrame({'A':[2,5],'B':[1,3]})
df1
# Out:
#    A  B
# 0  2  1
# 1  5  3

# %%
df2 = pd.DataFrame({'A':[1,3],'B':[0,6]})
df2
# Out:
#    A  B
# 0  1  0
# 1  3  6

# %%
df1.combine(df2, lambda x,y : x if x.sum() < y.sum() else y)
# Out:
#    A  B
# 0  1  1
# 1  3  3

# %%
df4 = pl.read_csv('netflix_titles.csv')
